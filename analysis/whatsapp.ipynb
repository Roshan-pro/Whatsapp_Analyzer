# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from zip_data.unzipdata import Data,UnzipData
path = r"C:\Users\rk186\OneDrive\Desktop\Whatappanalyzer\zip_data\WhatsApp Chat with Bakity Unity 🤝.zip"
extension = ".zip"

data_handler = Data.get_data(extension)
df = data_handler.ingest(path)
df.head()
# Out:
# 📂 Using file: Extracted_data\WhatsApp Chat with Bakity Unity 🤝.txt
# ✅ Chat saved as 'whatsapp_chat.csv'
#       Date      Time         Sender  \
# 0  4/12/25  11:12 AM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 2  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 3  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 4  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
#
#                                             Message
# 0                          You deleted this message
# 1                                   <Media omitted>
# 2  Webinar me ake capstone ka class puch raha hai 🤣
# 3                          You deleted this message
# 4                          You deleted this message

# %%
import pandas as  pd 
import seaborn as sns
from zip_data.unzipdata import Data,UnzipData
from wordcloud import WordCloud, STOPWORDS
from src.data_info import DataInformation,DataInfo,ISNULL,ValueCounts,DuplicatePresent
from src.feature_enginnering import FeautreEng,Repalacestrategy,SetDatesMonths
from src.top_senders import TopSenedr,Barplot
from src.mostfrequentwords import MostFrequentWords,MostFrequentWordsfromMembers,MostFrequentWordsinGroups
from src.correlationChats import WhatsappCorrelation,WhatsappMatrix
from src.messageActivityWeek import WeekMeassage,MembersWeeklyMessage
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
data=Data()
data=data.get_data(".zip")
data.ingest(r"C:\Users\rk186\OneDrive\Desktop\Whatappanalyzer\zip_data\WhatsApp Chat with Bakity Unity 🤝.zip")
# Out:
# 📂 Using file: Extracted_data\WhatsApp Chat with Bakity Unity 🤝.txt
# ✅ Chat saved as 'whatsapp_chat.csv'
#          Date      Time           Sender  \
# 0     4/12/25  11:12 AM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1     4/12/25   7:13 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 2     4/12/25   7:13 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 3     4/12/25   8:31 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 4     4/12/25   8:31 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# ...       ...       ...              ...
# 1566   7/2/25   4:04 PM  +91 91536 92861
# 1567   7/2/25   4:04 PM  +91 91423 53680
# 1568   7/2/25   4:23 PM  +91 91536 92861
# 1569   7/2/25   4:40 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1570   7/2/25   4:42 PM  +91 91536 92861
#
#                                                 Message
# 0                              You deleted this message
# 1                                       <Media omitted>
# 2      Webinar me ake capstone ka class puch raha hai 🤣
# 3                              You deleted this message
# 4                              You deleted this message
# ...

# %%
df = Data()
unzipped_data = df.get_data(".zip")
data = unzipped_data.ingest(r"C:\Users\rk186\OneDrive\Desktop\Whatappanalyzer\zip_data\WhatsApp Chat with Bakity Unity 🤝.zip")

# Now this works, because df is a DataFrame
data.head()
# Out:
# 📂 Using file: Extracted_data\WhatsApp Chat with Bakity Unity 🤝.txt
# ✅ Chat saved as 'whatsapp_chat.csv'
#       Date      Time         Sender  \
# 0  4/12/25  11:12 AM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 2  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 3  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 4  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
#
#                                             Message
# 0                          You deleted this message
# 1                                   <Media omitted>
# 2  Webinar me ake capstone ka class puch raha hai 🤣
# 3                          You deleted this message
# 4                          You deleted this message

# %%
data.head()
# Out:
#       Date      Time         Sender  \
# 0  4/12/25  11:12 AM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 2  4/12/25   7:13 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 3  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 4  4/12/25   8:31 PM  Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
#
#                                             Message
# 0                          You deleted this message
# 1                                   <Media omitted>
# 2  Webinar me ake capstone ka class puch raha hai 🤣
# 3                          You deleted this message
# 4                          You deleted this message

# %%
data_info=DataInformation(DataInfo())
data_info.info(data)
# Out:
# 2025-07-18 10:52:39,489 - INFO - Checking Information of Data.
# 2025-07-18 10:52:39,495 - INFO -
# Data's Information:
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1571 non-null   object
#  1   Time     1571 non-null   object
#  2   Sender   1571 non-null   object
#  3   Message  1571 non-null   object
# dtypes: object(4)
# memory usage: 49.2+ KB

# %%
data_info.set_strategy(ISNULL())
data_info.info(data)
# Out:
# 2025-07-18 10:52:39,508 - INFO - Checking whether Data has null value.
# 2025-07-18 10:52:39,513 - INFO -
# Number of Null values:
# Date       0
# Time       0
# Sender     0
# Message    0
# dtype: int64

# %%
data_info.set_strategy(DuplicatePresent())
data_info.info(data)
# Out:
# 2025-07-18 10:52:39,526 - INFO - Checking duplicate value present in Data.
# 2025-07-18 10:52:39,531 - INFO -
# Data's duplicate Values:
# 134

# %%
data_info.set_strategy(ValueCounts())
data_info.info(data)
# Out:
# 2025-07-18 10:52:39,541 - INFO - Most active members in group
# 2025-07-18 10:52:39,546 - ERROR -
# Most active memebers in group Sender
# +91 91536 92861            486
# ᴀᴅᴀʀꜱʜ😎......              317
# PRATAP KUMAR SINGH IITP    234
# +91 91423 53680            173
# Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛               85
# +91 99424 98114             83
# Piyush Raj😎 Iitp            80
# SAURABH MAURYA🚩             69
# +91 90650 64928             21
# +91 81681 54849             14
# +91 70439 45399              9
# Name: count, dtype: int64

# %%
with_date_months=FeautreEng(SetDatesMonths(data,"Date"))
with_date_months.apply()
# Out:
# 2025-07-18 10:52:39,562 - INFO - Making Date and Month new columns
#            Date      Time           Sender  \
# 0    2025-04-12  11:12 AM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1    2025-04-12   7:13 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 2    2025-04-12   7:13 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 3    2025-04-12   8:31 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 4    2025-04-12   8:31 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# ...         ...       ...              ...
# 1566 2025-07-02   4:04 PM  +91 91536 92861
# 1567 2025-07-02   4:04 PM  +91 91423 53680
# 1568 2025-07-02   4:23 PM  +91 91536 92861
# 1569 2025-07-02   4:40 PM    Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛
# 1570 2025-07-02   4:42 PM  +91 91536 92861
#
#                                                 Message        Day  Month
# 0                              You deleted this message   Saturday  April
# 1                                       <Media omitted>   Saturday  April
# 2      Webinar me ake capstone ka class puch raha hai 🤣   Saturday  April
# 3                              You deleted this message   Saturday  April
# ...

# %%
replacement_map = {
    "Message": {"<Media omitted>": "GIF or Scticker"},
    "Sender": {"Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛": "@Roshan yadav"}
}

with_date_months.set_strategy(Repalacestrategy(data,replacement_map))
with_date_months.apply()
# Out:
# 2025-07-18 10:52:39,619 - INFO - Replacing values using mapping: {'Message': {'<Media omitted>': 'GIF or Scticker'}, 'Sender': {'Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛': '@Roshan yadav'}}
#            Date      Time           Sender  \
# 0    2025-04-12  11:12 AM    @Roshan yadav
# 1    2025-04-12   7:13 PM    @Roshan yadav
# 2    2025-04-12   7:13 PM    @Roshan yadav
# 3    2025-04-12   8:31 PM    @Roshan yadav
# 4    2025-04-12   8:31 PM    @Roshan yadav
# ...         ...       ...              ...
# 1566 2025-07-02   4:04 PM  +91 91536 92861
# 1567 2025-07-02   4:04 PM  +91 91423 53680
# 1568 2025-07-02   4:23 PM  +91 91536 92861
# 1569 2025-07-02   4:40 PM    @Roshan yadav
# 1570 2025-07-02   4:42 PM  +91 91536 92861
#
#                                                 Message        Day  Month
# 0                              You deleted this message   Saturday  April
# 1                                       GIF or Scticker   Saturday  April
# ...

# %%
TopSenedr(Barplot()).plot(data,10)
# Out:
# 2025-07-18 10:52:39,644 - INFO - Preparing to plot bar graph of top 10 senders.
# c:\Users\rk186\OneDrive\Desktop\Whatappanalyzer\src\top_senders.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_5_senders.values,y=top_5_senders.index,palette="coolwarm",legend=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1571 non-null   datetime64[ns]
#  1   Time     1571 non-null   object
#  2   Sender   1571 non-null   object
#  3   Message  1571 non-null   object
#  4   Day      1571 non-null   object
#  5   Month    1571 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 73.8+ KB

# %%
most_common_words_in_group=MostFrequentWords(MostFrequentWordsinGroups())
most_common_words_in_group.checkFreqWords(data)
# Out:
# 2025-07-18 10:52:40,067 - INFO - Creating Wordcloud of most frequent Messages send in group.

# %%
most_common_words_in_group.set_strategy(MostFrequentWordsfromMembers("@Roshan yadav"))
most_common_words_in_group.checkFreqWords(data)
# Out:
# 2025-07-18 10:52:41,004 - INFO - Creating Wordcloud of most frequent Messages send by  group members.
# 2025-07-18 10:52:41,007 - INFO - Total messages sent by '@Roshan yadav': 85
# 2025-07-18 10:52:41,839 - INFO - Most active day by '@Roshan yadav': 2025-06-29 with 22 messages

# %%
member_week_message=WeekMeassage(MembersWeeklyMessage())
df = with_date_months.apply()
member_week_message.analysis(df, "@Roshan yadav")
# Out:
# 2025-07-18 10:52:41,853 - INFO - Replacing values using mapping: {'Message': {'<Media omitted>': 'GIF or Scticker'}, 'Sender': {'Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛': '@Roshan yadav'}}
# 2025-07-18 10:52:41,855 - INFO - Analysing @Roshan yadav weakly message.
# 2025-07-18 10:52:41,881 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\rk186\OneDrive\Desktop\Whatappanalyzer\src\messageActivityWeek.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=weekday_counts.index, y=weekday_counts.values, palette="coolwarm")
# ...

# %%
data1=with_date_months.apply()
# Out:
# 2025-07-18 11:00:02,177 - INFO - Replacing values using mapping: {'Message': {'<Media omitted>': 'GIF or Scticker'}, 'Sender': {'Ⓡ𝕽𝖔𝖘𝖍𝖆𝖓 𝖄𝖆𝖉𝖆𝖛': '@Roshan yadav'}}

# %%
message_counts = data1.groupby(["Day", "Sender"]).size().unstack(fill_value=0)
top_members = message_counts.sum().sort_values(ascending=False).head(6).index

filtered_df = message_counts[top_members]

corr=WhatsappMatrix(filtered_df)
corr.correlate()
# Out:
# 2025-07-18 11:00:06,206 - INFO - Finding correlation between chats
